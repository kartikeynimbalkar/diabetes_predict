# %%
# Supervised learning

# Two kinds of problems we solve
# 1. Classification problem:-target variable is categorical value
# eg:-predict wheather the customer will buy the product or not
# predict the type of the customer
# predict weather the custome will leave the company or not
# predict weather a person will buy a top or a shirt
# there are two types off clf problem
# 1. Binary clf and 2. Multiclass clf


# 2. Regression problem:-target variable is continuous value
# eg: predict the price of the house, predict the insurance premium,
# predict the sale in next quarter, predict the growth in next year

# %%
# SCIKIT LEARN LIBRARY
# Machine learning library for python

# Models/Algos for classification
# 1. Logistic Regression
# 2. Decision Tree classifier
# 3. Random Forest classifier
# 4. KNN classifier
# 5. Support Vector Machine classifier
# 6. Naive Bayes
# 7. Adaboost classifier
# 8. Gradient Boosting classifier


# Models/Algos for regression
# 1. Linear Regression
# 2. Ridge Regression
# 3. Lasso Regression
# 4. Elastic Net Regression
# 5. Decision Tree Regressor
# 6. Random Forest Regressor
# 7. KNN Regressor
# 8. Support Vector Machine Regressor
# 9. Adaboost Regressor
# 10. Gradient Boosting Regressor
# 11. XGBoost Regressor
# 12. LightGBM Regressor

# %%
import pandas as pd
import numpy as np

# %%
diab=pd.read_csv("/Diabetes_1.csv")

# %%
diab
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# weather data is clean or not

# Check Missing Values
diab.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#check duplicates
diab.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check data types of each column
diab.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# check descriptive analysis for my data
# this is only for num cols
# not for cat
diab.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
l=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']

for i in l:
  diab[i]=diab[i].replace(0,diab[i].median() )

# %%
# check descriptive analysis for my data again
diab.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.334635   94.652344
# std       3.369578   30.438286      12.096642       9.229014  105.547598
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      23.000000   30.500000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450911                  0.471876   33.240885    0.348958
# std      6.875366                  0.331329   11.760232    0.476951
# ...

# %%
# Start ML project for diabetes data

# i need to understand the steps in ML project

# Data loading
# Data Understanding
# Data Cleaning
# Data Exploration/visualization
# Data Preprocessing

# %%
# preprocessing the data

# split the data into inputs and a target col
X=diab.drop('Outcome',axis=1) # It contain input cols
y=diab['Outcome'] # It contain a target col

# %%
# Split the input and a target data into train parts and test parts

# why we split the data into train and test parts
# so that i can evaluate the accuracy of my model

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# I am going to load my model from scikit learn library
# load all clf models

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# whenever you want to create a project
# there are three steps you need to do

# 1. load/intialize the model
# 2. fit/train/feed the model
# 3. predict the model using test data
# 4. evaluate the model using metrics
# 5. once you figure out which model gives you the best metrics
# 5b. you can use that model for prediction

# %%
# intialize all the models

lr=LogisticRegression()
svc=SVC()
rf=RandomForestClassifier()
dt=DecisionTreeClassifier()
nb=GaussianNB()
knn=KNeighborsClassifier()
ada=AdaBoostClassifier()
gbc=GradientBoostingClassifier()

# %%
# train all the models
# when you train a model you need to feed it with training data
# (X_train & X_test)
lr.fit(X_train,y_train)
svc.fit(X_train,y_train)
rf.fit(X_train,y_train)
dt.fit(X_train,y_train)
nb.fit(X_train,y_train)
knn.fit(X_train,y_train)
ada.fit(X_train,y_train)
gbc.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GradientBoostingClassifier()

# %%
# Test my models
# during Testing I will only give test input data (X_test)
# then model will give me their solutions
# and then i am compare model sol'n with actual target data(y_test)

# evaluate each model by predict ouputs for the Test_data

lr_pred=lr.predict(X_test)
svc_pred=svc.predict(X_test)
rf_pred=rf.predict(X_test)
dt_pred=dt.predict(X_test)
nb_pred=nb.predict(X_test)
knn_pred=knn.predict(X_test)
ada_pred=ada.predict(X_test)
gbc_pred=gbc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(lr_pred,y_test))
print(accuracy_score(svc_pred,y_test))
print(accuracy_score(rf_pred,y_test))
print(accuracy_score(dt_pred,y_test))
print(accuracy_score(nb_pred,y_test))
print(accuracy_score(knn_pred,y_test))
print(accuracy_score(ada_pred,y_test))
print(accuracy_score(gbc_pred,y_test))
#
# Out:
# 0.7792207792207793
# 0.7922077922077922
# 0.7857142857142857
# 0.6818181818181818
# 0.7532467532467533
# 0.7467532467532467
# 0.7727272727272727
# 0.7792207792207793

# %%
import pickle
pickle.dump(svc,open('svc_diab.pkl','wb'))
